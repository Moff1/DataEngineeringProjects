# %%
import io
import json
import os
import sys
 
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload
from supabase import create_client, Client

# %%
client_ID = '560353252630-hjaf41u5edftkpbilerj89icdmrt8nvb.apps.googleusercontent.com'
client_secret = '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'

# %%
GOOGLE_CREDENTIALS_FILE = "oauth_credentials.json"   # OAuth client secret file
GOOGLE_TOKEN_FILE       = "token.json"         # cached token (auto-created)
GOOGLE_SCOPES           = ["https://www.googleapis.com/auth/drive.readonly"]
 
DRIVE_FOLDER_ID  = "1VswzOs1nkZLVIE-lt-CcJHFcxahKbsn-"            # Google Drive folder ID
FILE_NAME_FILTER = "Streaming_History_Audio"    # substring to match filenames
 
SUPABASE_URL     = "https://dljbothdbjqfvdzayihv.supabase.co"  # your Supabase project URL
SUPABASE_KEY     = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImRsamJvdGhkYmpxZnZkemF5aWh2Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3Nzg4MDAwMDAsImV4cCI6MjA5NDM3NjAwMH0.fyrpcykF1XrxSSHTBSCn2k36fabaqfokEvMDeKHRCPA"    # anon or service-role key
SUPABASE_TABLE   = "streaming_audio"         # target table name
 
BATCH_SIZE       = 500                         # rows per insert

# %%
def get_drive_service():
    """Authenticate with Google Drive and return a service object."""
    creds = None
 
    if os.path.exists(GOOGLE_TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(GOOGLE_TOKEN_FILE, GOOGLE_SCOPES)
 
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            if not os.path.exists(GOOGLE_CREDENTIALS_FILE):
                print(f"ERROR: '{GOOGLE_CREDENTIALS_FILE}' not found.")
                print("Download your OAuth credentials from Google Cloud Console.")
                sys.exit(1)
            flow = InstalledAppFlow.from_client_secrets_file(
                GOOGLE_CREDENTIALS_FILE, GOOGLE_SCOPES
            )
            creds = flow.run_local_server(port=0)
 
        with open(GOOGLE_TOKEN_FILE, "w") as f:
            f.write(creds.to_json())
 
    return build("drive", "v3", credentials=creds)

# %%
def list_matching_files(service, folder_id: str, name_filter: str) -> list[dict]:
    """Return all files in a Drive folder whose names contain name_filter."""
    query = f"'{folder_id}' in parents and trashed = false"
    files = []
    page_token = None
 
    while True:
        resp = service.files().list(
            q=query,
            fields="nextPageToken, files(id, name, size, mimeType)",
            pageToken=page_token,
        ).execute()
 
        for f in resp.get("files", []):
            if name_filter.lower() in f["name"].lower():
                files.append(f)
 
        page_token = resp.get("nextPageToken")
        if not page_token:
            break
 
    return files

# %%
def download_file_content(service, file_id: str) -> bytes:
    """Download a file from Google Drive and return its raw bytes."""
    request = service.files().get_media(fileId=file_id)
    buffer = io.BytesIO()
    downloader = MediaIoBaseDownload(buffer, request)
    done = False
    while not done:
        _, done = downloader.next_chunk()
    return buffer.getvalue()

# %%
def batch_upload(client: Client, table: str, records: list[dict], batch_size: int) -> tuple[int, int]:
    """Insert records into Supabase in batches. Returns (uploaded, errors)."""
    uploaded = 0
    errors = 0

    for i in range(0, len(records), batch_size):
        batch = [
            {
                "ts": r["ts"],
                "ms_played": r["ms_played"],
                "metadata_track_name": r["master_metadata_track_name"],
                "metadata_album_artist_name": r["master_metadata_album_artist_name"],
                "metadata_album_album_name": r["master_metadata_album_album_name"],
                "spotify_track_uri": r["spotify_track_uri"],
                "reason_start": r["reason_start"],
                "reason_end": r["reason_end"]
            }
            for r in records[i:i + batch_size]
        ]
        batch_num = i // batch_size + 1
        try:
            client.table(table).insert(batch).execute()
            uploaded += len(batch)
            print(f"    Batch {batch_num}: {len(batch)} rows inserted.")
        except Exception as e:
            errors += len(batch)
            print(f"    Batch {batch_num}: ERROR - {e}")

    return uploaded, errors

# %%
def main():
    print("── Google Drive -> Supabase Pipeline ──────────────────────────\n")
 
    # 1. Authenticate
    print("Authenticating with Google Drive...")
    drive_service = get_drive_service()
    print("Connecting to Supabase...")
    supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)
 
    # 2. Find matching files
    print(f"\nScanning folder: {DRIVE_FOLDER_ID}")
    print(f"Filter: '{FILE_NAME_FILTER}'\n")
    files = list_matching_files(drive_service, DRIVE_FOLDER_ID, FILE_NAME_FILTER)
 
    if not files:
        print("No matching files found. Check your folder ID and filter.")
        return
 
    print(f"Found {len(files)} matching file(s):\n")
    for f in files:
        size_kb = int(f.get("size", 0)) // 1024
        print(f"  {f['name']}  ({size_kb} KB)")
 
    # 3. Process each file
    total_uploaded = 0
    total_errors = 0
 
    print()
    for idx, file in enumerate(files, 1):
        print(f"[{idx}/{len(files)}] {file['name']}")
 
        try:
            raw = download_file_content(drive_service, file["id"])
            records = json.loads(raw.decode("utf-8"))
        except json.JSONDecodeError as e:
            print(f"  SKIP — JSON parse error: {e}")
            continue
        except Exception as e:
            print(f"  SKIP — download error: {e}")
            continue
 
        if not isinstance(records, list):
            print(f"  SKIP — expected a JSON array, got {type(records).__name__}")
            continue
 
        print(f"  {len(records):,} records — uploading in batches of {BATCH_SIZE}...")
        uploaded, errors = batch_upload(supabase, SUPABASE_TABLE, records, BATCH_SIZE)
        total_uploaded += uploaded
        total_errors += errors
        print(f"  Done: {uploaded:,} uploaded, {errors} error(s).\n")
 
    # 4. Summary
    print("── Summary ─────────────────────────────────────────────────────")
    print(f"  Files processed : {len(files)}")
    print(f"  Total uploaded  : {total_uploaded:,} rows")
    print(f"  Total errors    : {total_errors}")
    print(f"  Table           : {SUPABASE_TABLE}")
    print("────────────────────────────────────────────────────────────────")
 
 
if __name__ == "__main__":
    main()
# Out:
# ── Google Drive -> Supabase Pipeline ──────────────────────────
#
# Authenticating with Google Drive...
# Connecting to Supabase...
#
# Scanning folder: 1VswzOs1nkZLVIE-lt-CcJHFcxahKbsn-
# Filter: 'Streaming_History_Audio'
#
# Found 27 matching file(s):
#
#   Streaming_History_Audio_2025_3.json  (1731 KB)
#   Streaming_History_Audio_2025.json  (12476 KB)
#   Streaming_History_Audio_2025_1.json  (12478 KB)
#   Streaming_History_Audio_2026_1.json  (1832 KB)
#   Streaming_History_Audio_2025_2.json  (12477 KB)
#   Streaming_History_Audio_2026.json  (12462 KB)
#   Streaming_History_Audio_2024_2.json  (12479 KB)
#   Streaming_History_Audio_2024_3.json  (11572 KB)
#   Streaming_History_Audio_2024_1.json  (12486 KB)
#   Streaming_History_Audio_2023_2.json  (12494 KB)
#   Streaming_History_Audio_2023.json  (12499 KB)
#   Streaming_History_Audio_2024.json  (12482 KB)
#   Streaming_History_Audio_2023_4.json  (2700 KB)
#   Streaming_History_Audio_2023_1.json  (12494 KB)
#   Streaming_History_Audio_2023_3.json  (12495 KB)
#   Streaming_History_Audio_2022_3.json  (4109 KB)
#   Streaming_History_Audio_2022.json  (12436 KB)
#   Streaming_History_Audio_2020.json  (7164 KB)
#   Streaming_History_Audio_2018.json  (1 KB)
#   Streaming_History_Audio_2021_3.json  (3560 KB)
#   Streaming_History_Audio_2022_1.json  (12464 KB)
#   Streaming_History_Audio_2015.json  (294 KB)
#   Streaming_History_Audio_2022_2.json  (12456 KB)
#   Streaming_History_Audio_2021.json  (12440 KB)
#   Streaming_History_Audio_2019.json  (1 KB)
#   Streaming_History_Audio_2021_1.json  (12431 KB)
#   Streaming_History_Audio_2021_2.json  (12433 KB)
#
# [1/27] Streaming_History_Audio_2025_3.json
#   2,236 records — uploading in batches of 500...
#     Batch 1: ERROR - {'message': 'invalid input syntax for type bigint: "2025-06-16T20:27:23Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 2: ERROR - {'message': 'invalid input syntax for type bigint: "2025-09-08T00:50:25Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 3: ERROR - {'message': 'invalid input syntax for type bigint: "2025-10-20T11:05:21Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 4: ERROR - {'message': 'invalid input syntax for type bigint: "2025-10-29T00:22:24Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 5: ERROR - {'message': 'invalid input syntax for type bigint: "2025-12-04T03:37:30Z"', 'code': '22P02', 'hint': None, 'details': None}
#   Done: 0 uploaded, 2236 error(s).
#
# [2/27] Streaming_History_Audio_2025.json
#   16,019 records — uploading in batches of 500...
#     Batch 1: ERROR - {'message': 'invalid input syntax for type bigint: "2025-01-21T11:54:20Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 2: ERROR - {'message': 'invalid input syntax for type bigint: "2025-02-16T17:58:13Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 3: ERROR - {'message': 'invalid input syntax for type bigint: "2025-03-31T21:25:15Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 4: ERROR - {'message': 'invalid input syntax for type bigint: "2025-08-20T01:11:02Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 5: ERROR - {'message': 'invalid input syntax for type bigint: "2025-09-24T23:42:30Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 6: ERROR - {'message': 'invalid input syntax for type bigint: "2025-11-20T22:24:40Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 7: ERROR - {'message': 'invalid input syntax for type bigint: "2025-12-18T23:40:40Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 8: ERROR - {'message': 'invalid input syntax for type bigint: "2025-12-23T20:09:15Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 9: ERROR - {'message': 'invalid input syntax for type bigint: "2025-01-04T23:24:06Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 10: ERROR - {'message': 'invalid input syntax for type bigint: "2025-01-24T12:28:27Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 11: ERROR - {'message': 'invalid input syntax for type bigint: "2025-02-14T02:01:00Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 12: ERROR - {'message': 'invalid input syntax for type bigint: "2025-04-09T11:37:45Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 13: ERROR - {'message': 'invalid input syntax for type bigint: "2025-05-28T11:48:19Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 14: ERROR - {'message': 'invalid input syntax for type bigint: "2025-06-02T11:28:43Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 15: ERROR - {'message': 'invalid input syntax for type bigint: "2025-07-22T23:32:23Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 16: ERROR - {'message': 'invalid input syntax for type bigint: "2025-08-01T12:03:57Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 17: ERROR - {'message': 'invalid input syntax for type bigint: "2025-10-22T11:58:56Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 18: ERROR - {'message': 'invalid input syntax for type bigint: "2025-11-27T22:13:50Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 19: ERROR - {'message': 'invalid input syntax for type bigint: "2025-01-16T12:41:10Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 20: ERROR - {'message': 'invalid input syntax for type bigint: "2025-03-01T21:15:04Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 21: ERROR - {'message': 'invalid input syntax for type bigint: "2025-03-06T12:02:39Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 22: ERROR - {'message': 'invalid input syntax for type bigint: "2025-03-09T17:14:22Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 23: ERROR - {'message': 'invalid input syntax for type bigint: "2025-04-30T11:43:22Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 24: ERROR - {'message': 'invalid input syntax for type bigint: "2025-05-22T11:44:05Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 25: ERROR - {'message': 'invalid input syntax for type bigint: "2025-06-10T11:48:42Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 26: ERROR - {'message': 'invalid input syntax for type bigint: "2025-09-15T12:04:51Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 27: ERROR - {'message': 'invalid input syntax for type bigint: "2025-10-17T01:03:33Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 28: ERROR - {'message': 'invalid input syntax for type bigint: "2025-11-12T22:40:40Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 29: ERROR - {'message': 'invalid input syntax for type bigint: "2025-01-09T00:02:51Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 30: ERROR - {'message': 'invalid input syntax for type bigint: "2025-02-18T02:40:02Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 31: ERROR - {'message': 'invalid input syntax for type bigint: "2025-02-20T22:28:58Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 32: ERROR - {'message': 'invalid input syntax for type bigint: "2025-06-19T15:56:02Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 33: ERROR - {'message': 'invalid input syntax for type bigint: "2025-06-20T23:15:07Z"', 'code': '22P02', 'hint': None, 'details': None}
#   Done: 0 uploaded, 16019 error(s).
#
# [3/27] Streaming_History_Audio_2025_1.json
#   16,030 records — uploading in batches of 500...
#     Batch 1: ERROR - {'message': 'invalid input syntax for type bigint: "2025-06-20T23:38:44Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 2: ERROR - {'message': 'invalid input syntax for type bigint: "2025-07-04T13:47:54Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 3: ERROR - {'message': 'invalid input syntax for type bigint: "2025-08-09T18:47:39Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 4: ERROR - {'message': 'invalid input syntax for type bigint: "2025-10-14T20:59:50Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 5: ERROR - {'message': 'invalid input syntax for type bigint: "2025-10-28T11:46:04Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 6: ERROR - {'message': 'invalid input syntax for type bigint: "2025-12-10T21:24:11Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 7: ERROR - {'message': 'invalid input syntax for type bigint: "2025-01-31T12:38:52Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 8: ERROR - {'message': 'invalid input syntax for type bigint: "2025-02-05T00:04:38Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 9: ERROR - {'message': 'invalid input syntax for type bigint: "2025-04-28T12:00:28Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 10: ERROR - {'message': 'invalid input syntax for type bigint: "2025-05-02T00:51:28Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 11: ERROR - {'message': 'invalid input syntax for type bigint: "2025-05-24T20:53:07Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 12: ERROR - {'message': 'invalid input syntax for type bigint: "2025-06-06T12:20:06Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 13: ERROR - {'message': 'invalid input syntax for type bigint: "2025-07-17T19:09:35Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 14: ERROR - {'message': 'invalid input syntax for type bigint: "2025-09-09T13:01:14Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 15: ERROR - {'message': 'invalid input syntax for type bigint: "2025-09-22T12:24:28Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 16: ERROR - {'message': 'invalid input syntax for type bigint: "2025-12-29T22:10:40Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 17: ERROR - {'message': 'invalid input syntax for type bigint: "2025-01-06T12:21:37Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 18: ERROR - {'message': 'invalid input syntax for type bigint: "2025-04-07T23:49:41Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 19: ERROR - {'message': 'invalid input syntax for type bigint: "2025-04-16T21:23:38Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 20: ERROR - {'message': 'invalid input syntax for type bigint: "2025-04-22T23:28:27Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 21: ERROR - {'message': 'invalid input syntax for type bigint: "2025-07-05T22:55:20Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 22: ERROR - {'message': 'invalid input syntax for type bigint: "2025-07-11T21:55:00Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 23: ERROR - {'message': 'invalid input syntax for type bigint: "2025-07-14T12:08:35Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 24: ERROR - {'message': 'invalid input syntax for type bigint: "2025-08-03T00:24:52Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 25: ERROR - {'message': 'invalid input syntax for type bigint: "2025-09-23T12:04:29Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 26: ERROR - {'message': 'invalid input syntax for type bigint: "2025-11-04T01:43:49Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 27: ERROR - {'message': 'invalid input syntax for type bigint: "2025-12-02T11:45:37Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 28: ERROR - {'message': 'invalid input syntax for type bigint: "2025-01-12T02:41:41Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 29: ERROR - {'message': 'invalid input syntax for type bigint: "2025-02-25T01:15:13Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 30: ERROR - {'message': 'invalid input syntax for type bigint: "2025-02-27T13:07:20Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 31: ERROR - {'message': 'invalid input syntax for type bigint: "2025-04-12T12:49:48Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 32: ERROR - {'message': 'invalid input syntax for type bigint: "2025-04-18T16:54:21Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 33: ERROR - {'message': 'invalid input syntax for type bigint: "2025-05-05T18:09:32Z"', 'code': '22P02', 'hint': None, 'details': None}
#   Done: 0 uploaded, 16030 error(s).
#
# [4/27] Streaming_History_Audio_2026_1.json
#   2,342 records — uploading in batches of 500...
#     Batch 1: ERROR - {'message': 'invalid input syntax for type bigint: "2026-02-04T21:06:50Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 2: ERROR - {'message': 'invalid input syntax for type bigint: "2026-02-22T00:14:41Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 3: ERROR - {'message': 'invalid input syntax for type bigint: "2026-02-28T17:08:41Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 4: ERROR - {'message': 'invalid input syntax for type bigint: "2026-01-27T14:52:09Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 5: ERROR - {'message': 'invalid input syntax for type bigint: "2026-04-24T23:47:00Z"', 'code': '22P02', 'hint': None, 'details': None}
#   Done: 0 uploaded, 2342 error(s).
#
# [5/27] Streaming_History_Audio_2025_2.json
#   16,023 records — uploading in batches of 500...
#     Batch 1: ERROR - {'message': 'invalid input syntax for type bigint: "2025-05-05T21:22:03Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 2: ERROR - {'message': 'invalid input syntax for type bigint: "2025-05-18T16:35:53Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 3: ERROR - {'message': 'invalid input syntax for type bigint: "2025-07-17T22:52:59Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 4: ERROR - {'message': 'invalid input syntax for type bigint: "2025-07-18T22:14:11Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 5: ERROR - {'message': 'invalid input syntax for type bigint: "2025-07-26T16:03:10Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 6: ERROR - {'message': 'invalid input syntax for type bigint: "2025-08-19T11:44:26Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 7: ERROR - {'message': 'invalid input syntax for type bigint: "2025-01-30T12:39:00Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 8: ERROR - {'message': 'invalid input syntax for type bigint: "2025-02-28T12:07:08Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 9: ERROR - {'message': 'invalid input syntax for type bigint: "2025-03-07T22:40:05Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 10: ERROR - {'message': 'invalid input syntax for type bigint: "2025-03-18T16:03:50Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 11: ERROR - {'message': 'invalid input syntax for type bigint: "2025-05-08T02:24:26Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 12: ERROR - {'message': 'invalid input syntax for type bigint: "2025-06-17T20:30:18Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 13: ERROR - {'message': 'invalid input syntax for type bigint: "2025-06-27T11:45:26Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 14: ERROR - {'message': 'invalid input syntax for type bigint: "2025-06-30T00:34:47Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 15: ERROR - {'message': 'invalid input syntax for type bigint: "2025-08-04T11:39:43Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 16: ERROR - {'message': 'invalid input syntax for type bigint: "2025-11-06T12:26:25Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 17: ERROR - {'message': 'invalid input syntax for type bigint: "2025-11-28T19:40:21Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 18: ERROR - {'message': 'invalid input syntax for type bigint: "2025-01-17T22:19:52Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 19: ERROR - {'message': 'invalid input syntax for type bigint: "2025-02-08T18:16:50Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 20: ERROR - {'message': 'invalid input syntax for type bigint: "2025-03-28T21:18:16Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 21: ERROR - {'message': 'invalid input syntax for type bigint: "2025-06-08T00:30:11Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 22: ERROR - {'message': 'invalid input syntax for type bigint: "2025-06-23T20:22:10Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 23: ERROR - {'message': 'invalid input syntax for type bigint: "2025-07-30T20:21:10Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 24: ERROR - {'message': 'invalid input syntax for type bigint: "2025-10-03T12:16:31Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 25: ERROR - {'message': 'invalid input syntax for type bigint: "2025-11-09T21:37:52Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 26: ERROR - {'message': 'invalid input syntax for type bigint: "2025-11-30T03:42:18Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 27: ERROR - {'message': 'invalid input syntax for type bigint: "2025-01-13T21:47:39Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 28: ERROR - {'message': 'invalid input syntax for type bigint: "2025-02-11T23:03:12Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 29: ERROR - {'message': 'invalid input syntax for type bigint: "2025-02-13T03:11:35Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 30: ERROR - {'message': 'invalid input syntax for type bigint: "2025-03-11T23:55:37Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 31: ERROR - {'message': 'invalid input syntax for type bigint: "2025-03-24T23:52:15Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 32: ERROR - {'message': 'invalid input syntax for type bigint: "2025-05-20T11:30:20Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 33: ERROR - {'message': 'invalid input syntax for type bigint: "2025-06-16T18:08:17Z"', 'code': '22P02', 'hint': None, 'details': None}
#   Done: 0 uploaded, 16023 error(s).
#
# [6/27] Streaming_History_Audio_2026.json
#   15,916 records — uploading in batches of 500...
#     Batch 1: ERROR - {'message': 'invalid input syntax for type bigint: "2026-01-22T14:53:57Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 2: ERROR - {'message': 'invalid input syntax for type bigint: "2026-03-11T09:50:47Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 3: ERROR - {'message': 'invalid input syntax for type bigint: "2026-03-17T21:28:18Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 4: ERROR - {'message': 'invalid input syntax for type bigint: "2026-04-05T20:41:45Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 5: ERROR - {'message': 'invalid input syntax for type bigint: "2026-01-02T12:51:02Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 6: ERROR - {'message': 'invalid input syntax for type bigint: "2026-02-14T18:40:09Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 7: ERROR - {'message': 'invalid input syntax for type bigint: "2026-03-04T12:27:57Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 8: ERROR - {'message': 'invalid input syntax for type bigint: "2026-03-31T00:14:41Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 9: ERROR - {'message': 'invalid input syntax for type bigint: "2026-01-12T00:42:24Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 10: ERROR - {'message': 'invalid input syntax for type bigint: "2026-02-06T23:23:35Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 11: ERROR - {'message': 'invalid input syntax for type bigint: "2026-02-26T00:57:08Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 12: ERROR - {'message': 'invalid input syntax for type bigint: "2026-03-13T20:27:38Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 13: ERROR - {'message': 'invalid input syntax for type bigint: "2026-04-28T23:25:16Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 14: ERROR - {'message': 'invalid input syntax for type bigint: "2026-01-15T12:45:11Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 15: ERROR - {'message': 'invalid input syntax for type bigint: "2026-03-30T12:44:19Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 16: ERROR - {'message': 'invalid input syntax for type bigint: "2026-01-29T12:44:28Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 17: ERROR - {'message': 'invalid input syntax for type bigint: "2026-02-12T17:09:27Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 18: ERROR - {'message': 'invalid input syntax for type bigint: "2026-03-28T13:14:36Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 19: ERROR - {'message': 'invalid input syntax for type bigint: "2026-01-20T11:11:40Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 20: ERROR - {'message': 'invalid input syntax for type bigint: "2026-02-07T23:35:33Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 21: ERROR - {'message': 'invalid input syntax for type bigint: "2026-03-09T17:50:52Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 22: ERROR - {'message': 'invalid input syntax for type bigint: "2026-03-22T00:31:00Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 23: ERROR - {'message': 'invalid input syntax for type bigint: "2026-01-17T00:01:57Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 24: ERROR - {'message': 'invalid input syntax for type bigint: "2026-01-31T00:14:23Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 25: ERROR - {'message': 'invalid input syntax for type bigint: "2026-02-19T12:28:32Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 26: ERROR - {'message': 'invalid input syntax for type bigint: "2026-03-05T22:23:44Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 27: ERROR - {'message': 'invalid input syntax for type bigint: "2026-04-23T18:44:33Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 28: ERROR - {'message': 'invalid input syntax for type bigint: "2026-01-09T18:29:11Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 29: ERROR - {'message': 'invalid input syntax for type bigint: "2026-04-10T17:41:48Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 30: ERROR - {'message': 'invalid input syntax for type bigint: "2026-04-18T00:40:22Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 31: ERROR - {'message': 'invalid input syntax for type bigint: "2026-01-04T21:07:44Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 32: ERROR - {'message': 'invalid input syntax for type bigint: "2026-01-07T12:13:16Z"', 'code': '22P02', 'hint': None, 'details': None}
#   Done: 0 uploaded, 15916 error(s).
#
# [7/27] Streaming_History_Audio_2024_2.json
#   16,036 records — uploading in batches of 500...
#     Batch 1: ERROR - {'message': 'invalid input syntax for type bigint: "2024-02-11T16:39:48Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 2: ERROR - {'message': 'invalid input syntax for type bigint: "2024-02-23T21:04:29Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 3: ERROR - {'message': 'invalid input syntax for type bigint: "2024-03-15T23:48:08Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 4: ERROR - {'message': 'invalid input syntax for type bigint: "2024-04-27T14:36:18Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 5: ERROR - {'message': 'invalid input syntax for type bigint: "2024-05-06T14:20:05Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 6: ERROR - {'message': 'invalid input syntax for type bigint: "2024-05-07T17:49:06Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 7: ERROR - {'message': 'invalid input syntax for type bigint: "2024-07-13T06:13:53Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch
z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 14: ERROR - {'message': 'invalid input syntax for type bigint: "2023-06-27T15:05:15Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 15: ERROR - {'message': 'invalid input syntax for type bigint: "2023-06-28T23:34:09Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 16: ERROR - {'message': 'invalid input syntax for type bigint: "2023-06-30T16:57:02Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 17: ERROR - {'message': 'invalid input syntax for type bigint: "2023-10-01T11:59:37Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 18: ERROR - {'message': 'invalid input syntax for type bigint: "2023-10-17T22:01:12Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 19: ERROR - {'message': 'invalid input syntax for type bigint: "2023-10-19T00:24:57Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 20: ERROR - {'message': 'invalid input syntax for type bigint: "2023-10-21T15:10:22Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 21: ERROR - {'message': 'invalid input syntax for type bigint: "2023-01-17T11:57:23Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 22: ERROR - {'message': 'invalid input syntax for type bigint: "2023-01-19T11:11:29Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 23: ERROR - {'message': 'invalid input syntax for type bigint: "2023-03-25T14:28:22Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 24: ERROR - {'message': 'invalid input syntax for type bigint: "2023-03-28T21:18:02Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 25: ERROR - {'message': 'invalid input syntax for type bigint: "2023-04-29T16:57:45Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 26: ERROR - {'message': 'invalid input syntax for type bigint: "2023-05-30T13:39:13Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 27: ERROR - {'message': 'invalid input syntax for type bigint: "2023-06-02T21:34:56Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 28: ERROR - {'message': 'invalid input syntax for type bigint: "2023-08-20T22:48:42Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 29: ERROR - {'message': 'invalid input syntax for type bigint: "2023-08-23T18:40:16Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 30: ERROR - {'message': 'invalid input syntax for type bigint: "2023-08-31T11:33:15Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 31: ERROR - {'message': 'invalid input syntax for type bigint: "2023-09-09T14:42:57Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 32: ERROR - {'message': 'invalid input syntax for type bigint: "2023-09-11T22:59:32Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 33: ERROR - {'message': 'invalid input syntax for type bigint: "2023-09-13T22:37:34Z"', 'code': '22P02', 'hint': None, 'details': None}
#   Done: 0 uploaded, 16152 error(s).
#
# [11/27] Streaming_History_Audio_2023.json
#   16,182 records — uploading in batches of 500...
#     Batch 1: ERROR - {'message': 'invalid input syntax for type bigint: "2023-02-13T15:35:02Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 2: ERROR - {'message': 'invalid input syntax for type bigint: "2023-02-15T11:49:24Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 3: ERROR - {'message': 'invalid input syntax for type bigint: "2023-02-17T04:56:37Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 4: ERROR - {'message': 'invalid input syntax for type bigint: "2023-03-01T22:20:16Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 5: ERROR - {'message': 'invalid input syntax for type bigint: "2023-03-03T16:52:14Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 6: ERROR - {'message': 'invalid input syntax for type bigint: "2023-07-02T14:15:24Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 7: ERROR - {'message': 'invalid input syntax for type bigint: "2023-07-04T22:37:16Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 8: ERROR - {'message': 'invalid input syntax for type bigint: "2023-09-21T11:47:38Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 9: ERROR - {'message': 'invalid input syntax for type bigint: "2023-09-23T17:48:15Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 10: ERROR - {'message': 'invalid input syntax for type bigint: "2023-09-26T22:45:52Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 11: ERROR - {'message': 'invalid input syntax for type bigint: "2023-09-28T16:02:14Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 12: ERROR - {'message': 'invalid input syntax for type bigint: "2023-09-29T19:15:26Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 13: ERROR - {'message': 'invalid input syntax for type bigint: "2023-10-30T10:32:50Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 14: ERROR - {'message': 'invalid input syntax for type bigint: "2023-11-10T23:23:25Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 15: ERROR - {'message': 'invalid input syntax for type bigint: "2023-11-14T17:08:36Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 16: ERROR - {'message': 'invalid input syntax for type bigint: "2023-11-21T17:45:31Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 17: ERROR - {'message': 'invalid input syntax for type bigint: "2023-02-04T15:37:56Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 18: ERROR - {'message': 'invalid input syntax for type bigint: "2023-02-07T14:32:32Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 19: ERROR - {'message': 'invalid input syntax for type bigint: "2023-04-16T01:51:47Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 20: ERROR - {'message': 'invalid input syntax for type bigint: "2023-04-20T22:44:43Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 21: ERROR - {'message': 'invalid input syntax for type bigint: "2023-05-08T15:12:21Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 22: ERROR - {'message': 'invalid input syntax for type bigint: "2023-06-18T17:49:56Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 23: ERROR - {'message': 'invalid input syntax for type bigint: "2023-06-21T22:28:44Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 24: ERROR - {'message': 'invalid input syntax for type bigint: "2023-09-16T16:30:04Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 25: ERROR - {'message': 'invalid input syntax for type bigint: "2023-09-19T10:16:44Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 26: ERROR - {'message': 'invalid input syntax for type bigint: "2023-11-04T15:23:00Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 27: ERROR - {'message': 'invalid input syntax for type bigint: "2023-12-28T15:10:16Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 28: ERROR - {'message': 'invalid input syntax for type bigint: "2023-01-30T16:08:19Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 29: ERROR - {'message': 'invalid input syntax for type bigint: "2023-02-03T15:00:38Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 30: ERROR - {'message': 'invalid input syntax for type bigint: "2023-04-24T00:17:11Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 31: ERROR - {'message': 'invalid input syntax for type bigint: "2023-05-11T13:13:01Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 32: ERROR - {'message': 'invalid input syntax for type bigint: "2023-05-16T14:11:48Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 33: ERROR - {'message': 'invalid input syntax for type bigint: "2023-05-18T20:44:43Z"', 'code': '22P02', 'hint': None, 'details': None}
#   Done: 0 uploaded, 16182 error(s).
#
# [12/27] Streaming_History_Audio_2024.json
#   16,060 records — uploading in batches of 500...
#     Batch 1: ERROR - {'message': 'invalid input syntax for type bigint: "2024-01-06T00:42:14Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 2: ERROR - {'message': 'invalid input syntax for type bigint: "2024-04-02T13:16:24Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 3: ERROR - {'message': 'invalid input syntax for type bigint: "2024-04-09T11:12:26Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 4: ERROR - {'message': 'invalid input syntax for type bigint: "2024-05-29T14:14:37Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 5: ERROR - {'message': 'invalid input syntax for type bigint: "2024-06-19T14:45:00Z"', 'code': '22P02', 'hint': None, 'details': None}
# ...
#     Batch 26: ERROR - {'message': 'invalid input syntax for type bigint: "2022-08-13T13:37:19Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 27: ERROR - {'message': 'invalid input syntax for type bigint: "2022-09-26T11:06:57Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 28: ERROR - {'message': 'invalid input syntax for type bigint: "2022-10-04T16:29:36Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 29: ERROR - {'message': 'invalid input syntax for type bigint: "2022-10-07T00:15:45Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 30: ERROR - {'message': 'invalid input syntax for type bigint: "2022-10-14T21:58:16Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 31: ERROR - {'message': 'invalid input syntax for type bigint: "2022-10-17T21:51:46Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 32: ERROR - {'message': 'invalid input syntax for type bigint: "2022-10-25T18:01:20Z"', 'code': '22P02', 'hint': None, 'details': None}
#   Done: 0 uploaded, 15870 error(s).
#
# [24/27] Streaming_History_Audio_2021.json
#   15,763 records — uploading in batches of 500...
#     Batch 1: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-17T16:54:16Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 2: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-18T19:03:28Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 3: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-19T20:57:13Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 4: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-21T22:20:14Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 5: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-23T02:49:13Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 6: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-23T21:45:17Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 7: ERROR - {'message': 'invalid input syntax for type bigint: "2021-07-27T00:20:40Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 8: ERROR - {'message': 'invalid input syntax for type bigint: "2021-10-26T21:22:09Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 9: ERROR - {'message': 'invalid input syntax for type bigint: "2021-11-18T11:22:49Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 10: ERROR - {'message': 'invalid input syntax for type bigint: "2021-11-29T17:45:11Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 11: ERROR - {'message': 'invalid input syntax for type bigint: "2021-12-17T01:00:24Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 12: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-26T14:01:44Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 13: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-26T22:42:28Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 14: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-28T13:13:14Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 15: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-29T16:38:27Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 16: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-29T22:26:53Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 17: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-31T15:24:38Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 18: ERROR - {'message': 'invalid input syntax for type bigint: "2021-02-01T22:47:47Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 19: ERROR - {'message': 'invalid input syntax for type bigint: "2021-05-24T17:45:12Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 20: ERROR - {'message': 'invalid input syntax for type bigint: "2021-05-26T13:05:54Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 21: ERROR - [WinError 10054] An existing connection was forcibly closed by the remote host
#     Batch 22: ERROR - {'message': 'invalid input syntax for type bigint: "2021-08-14T12:58:18Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 23: ERROR - {'message': 'invalid input syntax for type bigint: "2021-08-21T15:08:21Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 24: ERROR - {'message': 'invalid input syntax for type bigint: "2021-08-25T21:05:46Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 25: ERROR - {'message': 'invalid input syntax for type bigint: "2021-09-27T05:08:29Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 26: ERROR - {'message': 'invalid input syntax for type bigint: "2021-10-07T22:55:12Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 27: ERROR - {'message': 'invalid input syntax for type bigint: "2021-10-12T11:01:11Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 28: ERROR - {'message': 'invalid input syntax for type bigint: "2021-02-23T18:01:48Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 29: ERROR - {'message': 'invalid input syntax for type bigint: "2021-02-24T20:01:22Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 30: ERROR - {'message': 'invalid input syntax for type bigint: "2021-02-26T21:19:51Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 31: ERROR - {'message': 'invalid input syntax for type bigint: "2021-02-27T22:38:23Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 32: ERROR - {'message': 'invalid input syntax for type bigint: "2021-03-01T17:51:09Z"', 'code': '22P02', 'hint': None, 'details': None}
#   Done: 0 uploaded, 15763 error(s).
#
# [25/27] Streaming_History_Audio_2019.json
#   2 records — uploading in batches of 500...
#     Batch 1: ERROR - {'message': 'invalid input syntax for type bigint: "2019-07-17T02:11:44Z"', 'code': '22P02', 'hint': None, 'details': None}
#   Done: 0 uploaded, 2 error(s).
#
# [26/27] Streaming_History_Audio_2021_1.json
#   15,697 records — uploading in batches of 500...
#     Batch 1: ERROR - {'message': 'invalid input syntax for type bigint: "2021-03-02T17:30:08Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 2: ERROR - {'message': 'invalid input syntax for type bigint: "2021-03-26T14:37:34Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 3: ERROR - {'message': 'invalid input syntax for type bigint: "2021-03-30T10:27:29Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 4: ERROR - {'message': 'invalid input syntax for type bigint: "2021-04-24T00:01:46Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 5: ERROR - {'message': 'invalid input syntax for type bigint: "2021-09-21T11:23:50Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 6: ERROR - {'message': 'invalid input syntax for type bigint: "2021-10-31T15:35:52Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 7: ERROR - {'message': 'invalid input syntax for type bigint: "2021-11-05T19:16:22Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 8: ERROR - {'message': 'invalid input syntax for type bigint: "2021-03-04T11:22:37Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 9: ERROR - {'message': 'invalid input syntax for type bigint: "2021-03-06T05:34:49Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 10: ERROR - {'message': 'invalid input syntax for type bigint: "2021-03-08T23:44:01Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 11: ERROR - {'message': 'invalid input syntax for type bigint: "2021-06-28T18:01:22Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 12: ERROR - {'message': 'invalid input syntax for type bigint: "2021-08-31T10:31:35Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 13: ERROR - {'message': 'invalid input syntax for type bigint: "2021-09-01T21:07:21Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 14: ERROR - {'message': 'invalid input syntax for type bigint: "2021-09-04T14:40:46Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 15: ERROR - {'message': 'invalid input syntax for type bigint: "2021-10-22T15:38:59Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 16: ERROR - {'message': 'invalid input syntax for type bigint: "2021-12-18T17:09:55Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 17: ERROR - {'message': 'invalid input syntax for type bigint: "2021-12-21T15:13:36Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 18: ERROR - {'message': 'invalid input syntax for type bigint: "2021-12-24T01:04:50Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 19: ERROR - {'message': 'invalid input syntax for type bigint: "2021-12-26T19:31:46Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 20: ERROR - {'message': 'invalid input syntax for type bigint: "2021-12-29T14:33:08Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 21: ERROR - {'message': 'invalid input syntax for type bigint: "2021-12-31T15:47:39Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 22: ERROR - {'message': 'invalid input syntax for type bigint: "2021-02-09T23:52:04Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 23: ERROR - {'message': 'invalid input syntax for type bigint: "2021-02-10T23:23:05Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 24: ERROR - {'message': 'invalid input syntax for type bigint: "2021-02-12T01:27:24Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 25: ERROR - {'message': 'invalid input syntax for type bigint: "2021-02-13T21:57:43Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 26: ERROR - {'message': 'invalid input syntax for type bigint: "2021-02-15T22:24:07Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 27: ERROR - {'message': 'invalid input syntax for type bigint: "2021-03-20T13:08:48Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 28: ERROR - {'message': 'invalid input syntax for type bigint: "2021-03-22T22:23:49Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 29: ERROR - {'message': 'invalid input syntax for type bigint: "2021-04-17T22:51:06Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 30: ERROR - {'message': 'invalid input syntax for type bigint: "2021-04-22T19:29:48Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 31: ERROR - {'message': 'invalid input syntax for type bigint: "2021-05-29T21:57:47Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 32: ERROR - {'message': 'invalid input syntax for type bigint: "2021-06-01T18:20:09Z"', 'code': '22P02', 'hint': None, 'details': None}
#   Done: 0 uploaded, 15697 error(s).
#
# [27/27] Streaming_History_Audio_2021_2.json
#   15,712 records — uploading in batches of 500...
#     Batch 1: ERROR - {'message': 'invalid input syntax for type bigint: "2021-06-01T22:37:10Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 2: ERROR - {'message': 'invalid input syntax for type bigint: "2021-06-03T22:34:17Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 3: ERROR - {'message': 'invalid input syntax for type bigint: "2021-06-07T22:44:34Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 4: ERROR - {'message': 'invalid input syntax for type bigint: "2021-07-03T22:06:07Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 5: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-11T22:55:40Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 6: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-12T20:48:46Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 7: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-14T20:59:25Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 8: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-16T18:03:07Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 9: ERROR - {'message': 'invalid input syntax for type bigint: "2021-04-05T22:41:08Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 10: ERROR - {'message': 'invalid input syntax for type bigint: "2021-04-08T14:15:56Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 11: ERROR - {'message': 'invalid input syntax for type bigint: "2021-08-04T23:45:21Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 12: ERROR - {'message': 'invalid input syntax for type bigint: "2021-10-15T19:14:57Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 13: ERROR - {'message': 'invalid input syntax for type bigint: "2021-02-02T23:02:47Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 14: ERROR - {'message': 'invalid input syntax for type bigint: "2021-02-03T22:03:22Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 15: ERROR - {'message': 'invalid input syntax for type bigint: "2021-02-09T15:01:36Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 16: ERROR - {'message': 'invalid input syntax for type bigint: "2021-05-13T14:57:18Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 17: ERROR - {'message': 'invalid input syntax for type bigint: "2021-05-17T12:01:05Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 18: ERROR - {'message': 'invalid input syntax for type bigint: "2021-05-21T14:55:30Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 19: ERROR - {'message': 'invalid input syntax for type bigint: "2021-06-23T12:29:41Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 20: ERROR - {'message': 'invalid input syntax for type bigint: "2021-08-20T16:12:34Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 21: ERROR - {'message': 'invalid input syntax for type bigint: "2021-09-09T11:10:02Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 22: ERROR - {'message': 'invalid input syntax for type bigint: "2021-03-10T17:39:13Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 23: ERROR - {'message': 'invalid input syntax for type bigint: "2021-03-12T16:59:05Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 24: ERROR - {'message': 'invalid input syntax for type bigint: "2021-03-16T22:27:20Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 25: ERROR - {'message': 'invalid input syntax for type bigint: "2021-06-12T20:10:46Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 26: ERROR - {'message': 'invalid input syntax for type bigint: "2021-09-30T13:41:36Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 27: ERROR - {'message': 'invalid input syntax for type bigint: "2021-10-06T13:15:18Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 28: ERROR - {'message': 'invalid input syntax for type bigint: "2021-11-27T13:49:36Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 29: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-03T15:53:55Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 30: ERROR - {'message': 'invalid input syntax for type bigint: "2021-01-06T20:21:58Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 31: ERROR - {'message': 'invalid input syntax for type bigint: "2021-05-01T01:29:43Z"', 'code': '22P02', 'hint': None, 'details': None}
#     Batch 32: ERROR - {'message': 'invalid input syntax for type bigint: "2021-05-07T12:50:15Z"', 'code': '22P02', 'hint': None, 'details': None}
#   Done: 0 uploaded, 15712 error(s).
#
# ── Summary ─────────────────────────────────────────────────────
#   Files processed : 27
#   Total uploaded  : 0 rows
#   Total errors    : 313614
#   Table           : streaming_audio
# ────────────────────────────────────────────────────────────────
