# %%
import pandas as pd
import json

# %%
with open('C:\\Users\\JosephMoffatt\\OneDrive - Thought Logic\\Desktop\\GitHubRepos\\dataengineeringprojects\\DataEngineeringProjects\\auxdata\\Wrapped2025.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

data.keys()
# Out:
# dict_keys(['topArtists', 'topPodcasts', 'topTracks', 'yearlyMetrics', 'topAlbums', 'topGenres', 'clubs', 'listeningAge', 'party', 'topFanLeaderboard', 'topArtistRace', 'archiveReports'])

# %%
data['listeningAge']['listeningAge']
# Out:
# 34

# %%
for i in range(len(data['topArtistRace']['topArtists'])):
    print(data['topArtistRace']['topArtists'][i]['monthsStats'])
# Out:
# [{'rank': 4, 'month': 'JANUARY', 'trailSize': 'MEDIUM'}, {'rank': 4, 'month': 'FEBRUARY', 'trailSize': 'LOW'}, {'rank': 4, 'month': 'MARCH', 'trailSize': 'VERY_LOW'}, {'rank': 5, 'month': 'APRIL', 'trailSize': 'VERY_LOW'}, {'rank': 5, 'month': 'MAY', 'trailSize': 'LOW'}, {'rank': 5, 'month': 'JUNE', 'trailSize': 'LOW'}, {'rank': 4, 'month': 'JULY', 'trailSize': 'LOW'}, {'rank': 4, 'month': 'AUGUST', 'trailSize': 'LOW'}, {'rank': 4, 'month': 'SEPTEMBER', 'trailSize': 'LOW'}, {'rank': 3, 'month': 'OCTOBER', 'trailSize': 'LOW'}, {'rank': 3, 'month': 'NOVEMBER', 'trailSize': 'LOW'}]
# ...

# %%
data['party']['avgTrackPopularityScore']
# Out:
# 0.6734889149665833

# %%
data['party']['percentMusicSkips']
# Out:
# 53.04684066772461

# %%
data['party']['numListenedAlbums']
# Out:
# 5

# %%
data['party']['multilinguistRankingScore']
# Out:
# 4.533438600282509

# %%
data['party']['percentListenedExplicit']
# Out:
# 38.874926452706404

# %%
data['party']['absoluteChaosRankingScore']
# Out:
# 220.0

# %%
data['party']['percentPartyTracks']
# Out:
# 66.36611607819367

# %%
data['party']['percentListenedMorning']
# Out:
# 30.779837508862222

# %%
data['party']['percentListenedTopArtist']
# Out:
# 16.09

# %%
data['party']['totalNumListeningMinutes']
# Out:
# 44434

# %%
data['party']['totalNumListeningDays']
# Out:
# 311

# %%
data['party']['streakNumListeningDays']
# Out:
# 104

# %%
data['party']['numArtistsDiscovered']
# Out:
# 239

# %%
data['party']['percentHappyTracks']
# Out:
# 11.29310429096222

# %%
data['party']['numListenedAlbums']
# Out:
# 5

# %%
data['archiveReports']['archiveReports']
# Out:
# [{'columnQualifier': '20251003',
#   'minutesListened': 0,
#   'reason': 'BIGGEST_TOP_ARTIST_DAY',
#   'title': 'The day Chris Brown took the wheel and never let go',
#   'description': 'From a grateful gospel sunrise to a relentless Chris Brown relay—“Yeah 3x,” “Ayo,” and “Turn Up the Music” looping through morning, afternoon, and evening—your day barely left his orbit. 214 minutes, 76 tracks, 59 artists—your most Chris Brown–dominated day of the year, with 124 minutes spent in his company.',
#   'filedUnderTags': '[Chris Brown takeover, R&B marathon]'},
#  {'columnQualifier': '20250901',
#   'minutesListened': 0,
#   'reason': 'BIGGEST_PODCAST_LISTENING_DAY',
#   'title': 'The day you let podcasts run the show from sunrise to sunset',
# ...

# %%
data['topArtists']['topArtistUris']
# Out:
# ['spotify:artist:7bXgB6jMjp9ATFy66eO08Z',
#  'spotify:artist:4q3ewBCX7sLwd24euuV69X',
#  'spotify:artist:1mcTU81TzQhprhouKaTkpq',
#  'spotify:artist:23zg3TcAtWQy7J6upgbUnj',
#  'spotify:artist:1i8SpTcr7yvPOmcqrbnVXY']

# %%
data['topArtists']['numUniqueArtists']
# Out:
# 1142

# %%
data['topArtists']['topNPercentileFan']
# Out:
# 0.00044916457

# %%
data['topArtists']['topArtistMsPlayed']
# Out:
# 377446112

# %%
data['topPodcasts']['topPodcastsUri']
# Out:
# ['spotify:show:0SdDSgKLwkobIO5Jj8iPmP',
#  'spotify:show:6hakafjZG3OdpLxI6d3F70',
#  'spotify:show:6Gn7jHNS03HR40kP4BKZuV',
#  'spotify:show:0jFBhC63xxXsr2b1LGbirw']

# %%
data['topPodcasts']['topPodcastMilliseconds']
# Out:
# 183117949

# %%
data['topPodcasts']['topPodcastPercentage']
# Out:
# 0.008381954

# %%
data['topPodcasts']['totalPodcastMilliseconds']
# Out:
# 319158205

# %%
type(data['topTracks']['topTracks'])
# Out:
# list

# %%
data['yearlyMetrics']['totalMsListened']
# Out:
# 2666058408

# %%
data['topAlbums']['topAlbums']
# Out:
# ['spotify:album:5K79FLRUCSysQnVESLcTdb',
#  'spotify:album:3RQQmkQEvNCY4prGKE6oc5',
#  'spotify:album:6df0qvkMXoyHGt9J8cujZb',
#  'spotify:album:28HcjLBR5KSz5QrnRz7kSP',
#  'spotify:album:4PgleR09JVnm3zY1fW3XBA']

# %%
data['topAlbums']['numCompletedAlbums']
# Out:
# 5

# %%
data['topAlbums']['topAlbumTimePlayed']
# Out:
# 3100

# %%
data['topGenres']['topGenres']
# Out:
# ['spotify:concept:4tGuzC3aZ1xdc611ABp7MJ',
#  'spotify:concept:4QSYjWlU4Rc7s0BZq7V246',
#  'spotify:concept:1NgIsk9Q9EfUtyYG6hNPtg',
#  'spotify:concept:0mAkMQZ0RJ87Vfz7JQT1hY',
#  'spotify:concept:24pGOSaKeoU6bobuwqnMbJ']

# %%
data['topGenres']['totalNumGenres']
# Out:
# 220

# %%
data['clubs']['userClub']
# Out:
# 'FULL_CHARGE_CREW'

# %%
data['clubs']['percentInClub']
# Out:
# 0.20449942

# %%
data['clubs']['role']
# Out:
# 'COLLECTOR'

# %%
data['listeningAge']['listeningAge']
# Out:
# 34
