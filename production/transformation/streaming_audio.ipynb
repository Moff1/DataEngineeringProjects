# %%
import pandas as pd
import json

# %%
with open('C:\\Users\\JosephMoffatt\\OneDrive - Thought Logic\\Desktop\\GitHubRepos\\dataengineeringprojects\\DataEngineeringProjects\\auxdata\\Streaming_History_Audio_2022_1.json', 'r', encoding='utf-8') as f:
    extracted_fields = json.load(f)
    
print(extracted_fields[0])
# Out:
# {'ts': '2022-02-18T00:01:55Z', 'platform': 'iOS 15.2.1 (iPhone11,8)', 'ms_played': 960, 'conn_country': 'US', 'ip_addr': '174.215.150.184', 'master_metadata_track_name': 'Knock You Down', 'master_metadata_album_artist_name': 'Keri Hilson', 'master_metadata_album_album_name': 'In A Perfect World...', 'spotify_track_uri': 'spotify:track:58FUwmyGUqkt53YPUcm7cJ', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'audiobook_title': None, 'audiobook_uri': None, 'audiobook_chapter_uri': None, 'audiobook_chapter_title': None, 'reason_start': 'fwdbtn', 'reason_end': 'fwdbtn', 'shuffle': False, 'skipped': False, 'offline': False, 'offline_timestamp': None, 'incognito_mode': False}

# %%
df = pd.read_json('C:\\Users\\JosephMoffatt\\OneDrive - Thought Logic\\Desktop\\GitHubRepos\\dataengineeringprojects\\DataEngineeringProjects\\auxdata\\Streaming_History_Audio_2015.json')

df.head()
# Out:
#                      ts                             platform  ms_played  \
# 0  2015-01-20T22:06:44Z  Android OS 4.4 API 19 (LGE, LGL34C)      22981
# 1  2015-01-20T22:06:45Z  Android OS 4.4 API 19 (LGE, LGL34C)       2275
# 2  2015-01-20T22:06:48Z  Android OS 4.4 API 19 (LGE, LGL34C)          0
# 3  2015-01-20T22:06:48Z  Android OS 4.4 API 19 (LGE, LGL34C)          0
# 4  2015-01-20T22:06:48Z  Android OS 4.4 API 19 (LGE, LGL34C)          0
#
#   conn_country        ip_addr master_metadata_track_name  \
# 0           US  24.42.180.105                   Trophies
# 1           US  24.42.180.105                 Roger That
# 2           US  24.42.180.105                    BedRock
# 3           US  24.42.180.105                 We Alright
# 4           US  24.42.180.105                     Senile
#
#   master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                       Young Money                Rise Of An Empire
# ...

# %%
workingdf = df[['ts','ms_played','master_metadata_track_name','master_metadata_album_artist_name','master_metadata_album_album_name','spotify_track_uri','reason_start','reason_end']]
workingdf.head()
# Out:
#                      ts  ms_played master_metadata_track_name  \
# 0  2015-01-20T22:06:44Z      22981                   Trophies
# 1  2015-01-20T22:06:45Z       2275                 Roger That
# 2  2015-01-20T22:06:48Z          0                    BedRock
# 3  2015-01-20T22:06:48Z          0                 We Alright
# 4  2015-01-20T22:06:48Z          0                     Senile
#
#   master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                       Young Money                Rise Of An Empire
# 1                       Young Money               We Are Young Money
# 2                       Young Money               We Are Young Money
# 3                       Young Money                Rise Of An Empire
# 4                       Young Money                Rise Of An Empire
#
#                       spotify_track_uri reason_start reason_end
# 0  spotify:track:6HfOzLLjsaXsehIFEsrxTk    trackdone     fwdbtn
# ...

# %%
workingdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ts                                 370 non-null    object
#  1   ms_played                          370 non-null    int64
#  2   master_metadata_track_name         370 non-null    object
#  3   master_metadata_album_artist_name  370 non-null    object
#  4   master_metadata_album_album_name   370 non-null    object
#  5   spotify_track_uri                  370 non-null    object
#  6   reason_start                       370 non-null    object
#  7   reason_end                         370 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 23.3+ KB

# %%
len(workingdf)
# Out:
# 370

# %%
df_two = pd.read_json('C:\\Users\\JosephMoffatt\\OneDrive - Thought Logic\\Desktop\\GitHubRepos\\dataengineeringprojects\\DataEngineeringProjects\\auxdata\\Streaming_History_Audio_2022_1.json')

df_two.head()
# Out:
#                      ts                 platform  ms_played conn_country  \
# 0  2022-02-18T00:01:55Z  iOS 15.2.1 (iPhone11,8)        960           US
# 1  2022-02-18T00:01:56Z  iOS 15.2.1 (iPhone11,8)       1216           US
# 2  2022-02-18T00:01:57Z  iOS 15.2.1 (iPhone11,8)        960           US
# 3  2022-02-18T00:02:32Z  iOS 15.2.1 (iPhone11,8)      34517           US
# 4  2022-02-18T00:02:33Z  iOS 15.2.1 (iPhone11,8)       1173           US
#
#            ip_addr       master_metadata_track_name  \
# 0  174.215.150.184                   Knock You Down
# 1  174.215.150.184                        Your Love
# 2  174.215.150.184  Bartier Cardi (feat. 21 Savage)
# 3  174.215.150.184                          My Type
# 4  174.215.150.184            I Don't Fuck With You
#
#   master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                       Keri Hilson            In A Perfect World...
# 1                       Nicki Minaj                      Pink Friday
# ...

# %%
df_three = pd.read_json('C:\\Users\\JosephMoffatt\\OneDrive - Thought Logic\\Desktop\\GitHubRepos\\dataengineeringprojects\\DataEngineeringProjects\\auxdata\\Streaming_History_Audio_2026.json')

df_three.head()
# Out:
#                      ts platform  ms_played conn_country  \
# 0  2026-01-22T14:53:57Z      ios     353152           US
# 1  2026-01-22T14:57:42Z      ios     185830           US
# 2  2026-01-22T14:57:57Z      ios      17209           US
# 3  2026-01-22T14:57:59Z      ios       1834           US
# 4  2026-01-22T14:58:03Z      ios       3878           US
#
#                                 ip_addr       master_metadata_track_name  \
# 0  2601:c6:d37c:560:e863:19eb:1b1a:c021                       NADIE SABE
# 1  2601:c6:d37c:560:e863:19eb:1b1a:c021                     Long Journey
# 2  2601:c6:d37c:560:e863:19eb:1b1a:c021                  Love For A Thug
# 3  2601:c6:d37c:560:e863:19eb:1b1a:c021                    Favorite Song
# 4  2601:c6:d37c:560:e863:19eb:1b1a:c021  City of God (feat. Chris Brown)
#
#   master_metadata_album_artist_name     master_metadata_album_album_name  \
# 0                         Bad Bunny  nadie sabe lo que va a pasar mañana
# ...
